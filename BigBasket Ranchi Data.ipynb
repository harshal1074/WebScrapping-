# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36'}
r = requests.get('https://www.bigbasket.com/pc/beauty-hygiene/bath-hand-wash/talcum-powder/?nc=nb&page=',headers=header)

# %%
bsobj = BeautifulSoup(r.content, 'html.parser')
print(bsobj.prettify())
# Out:
# <!DOCTYPE html>
# <html class="scroll-smooth" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <title>
#    Buy Talcum Powder Products Online in India at Lowest Price  - bigbasket
#   </title>
#   <meta content="Buy Talcum Powder products online in India from bigbasket. Order Talcum Powder products online at great prices and have it delivered at your doorstep. " name="description"/>
#   <meta content="Buy Talcum Powder products online in India from bigbasket. Order Talcum Powder products online at great prices and have it delivered at your doorstep." name="keywords"/>
#   <link href="https://www.bigbasket.com/pc/beauty-hygiene/bath-hand-wash/talcum-powder/" rel="canonical"/>
#   <link href="https://www.bigbasket.com/pc/beauty-hygiene/bath-hand-wash/talcum-powder/?page=2" rel="next"/>
#   <link href="android-app://com.bigbasket.mobileapp/bigbasket/product_list/?type=pc&amp;slug=talcum-powder" rel="alternate"/>
# ...

# %%
product = bsobj.find_all('div', class_= 'SKUDeck___StyledDiv-sc-1e5d9gk-0 eA-dmzP')

# %%
import pandas as pd

title = []
name = []
rating = []
price = []
quantity = []
number_rating = []
discount_applied = []

for i in product:
    # Extracting the title content of the name element
    title_element = i.find('span', class_='Label-sc-15v1nk5-0 BrandName___StyledLabel2-sc-hssfrl-1 gJxZPQ keQNWn')
    title_value = title_element.text.strip() if title_element else None
    title.append(title_value)
    
    # Extracting the text content of the name element
    name_element = i.find('h3', class_='block m-0 line-clamp-2 font-regular text-base leading-sm text-darkOnyx-800 pt-0.5 h-full')
    name_value = name_element.text.strip() if name_element else None
    name.append(name_value)
    
    # Extracting the text content of the price element
    price_element = i.find('span', class_='Label-sc-15v1nk5-0 Pricing___StyledLabel-sc-pldi2d-1 gJxZPQ AypOi')
    price_value = price_element.text.strip() if price_element else None
    price.append(price_value)
    
    # Extracting the text content of the discount applied element
    discount_applied_element = i.find('span', class_='font-semibold lg:text-xs xl:text-sm leading-xxl xl:leading-md')
    discount_applied_value = discount_applied_element.text.strip() if discount_applied_element else None
    discount_applied.append(discount_applied_value)
    
    # Extracting the text content of the quantity element
    quantity_element = i.find('span', class_='Label-sc-15v1nk5-0 PackChanger___StyledLabel-sc-newjpv-1 gJxZPQ cWbtUx')
    quantity_value = quantity_element.text.strip() if quantity_element else None
    quantity.append(quantity_value)
    
    # Extracting the text content of the rating element
    rating_element = i.find('span', class_='Label-sc-15v1nk5-0 gJxZPQ')
    rating_value = rating_element.text.strip() if rating_element else None
    rating.append(rating_value)
    
    # Extracting the text content of the number rating element
    number_rating_element = i.find('span', class_='Label-sc-15v1nk5-0 ReviewsAndRatings___StyledLabel-sc-2rprpc-1 gJxZPQ egHBA-d')
    number_rating_value = number_rating_element.text.strip() if number_rating_element else None
    number_rating.append(number_rating_value)

# Create DataFrame
df = pd.DataFrame({
    'Title': title,
    'Name': name,
    'Price': price,
    'Discount_applied': discount_applied,
    'Quantity': quantity,
    'Rating': rating,
    'Number_rating': number_rating,
})


# Print DataFrame
df
# Out:
#                Title                                               Name  \
# 0              Ponds                          Dreamflower Fragrant Talc
# 1              Ponds                               Magic Freshness Talc
# 2              Nycil      Germ Expert Prickly Heat Powder - Cool Herbal
# 3     Yardley London  Morning Dew Perfumed Talc for Women| 97% Natur...
# 4     Yardley London  Gentleman Deodorant Talc - Classic, Refreshing...
# 5              Ponds                             Talc - Sandal Radiance
# 6     Yardley London           English Lavender Perfumed Talc for Women
# 7                Axe                       Signature Denim Cologne Talc
# 8           Navratna                             Cool Talc - Mint Fresh
# 9         Dermi Cool              Prickly Heat Powder Soothing Lavender
# 10        Enchanteur  Romantic Perfumed Talcum Powder with Floral Fr...
# 11             Ponds                               Ponds Starlight Talc
# ...

# %%
df.to_csv('Talcum_powder - BigBasket.csv', index=False)
